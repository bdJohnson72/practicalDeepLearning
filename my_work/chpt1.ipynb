# %%
# Week 1 questions

# %% [markdown]
# Q3: What are the requirements for parallel distributed processing
# It is challenge to write programs that appproximate what our brain does -recognize a shape. PDP was a framework that
# would lead to neural networks. The authors of PDP had these requirements
# 1. A set of processing Units
# 2. A state of activation
# 3. An output function for each unit
# 4. A pattern of connectivity among units
# 5. A propagation rule
# 6. An activation rule
# 7. A learning rule
# 8. An enviroment to operate in

# %% [markdown]
# Q4: What were theoretical misunderstandings that held back Deep Learning
# I feel like I don't really understand this but it had to do with the number of layers in a neural network

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Q6: What is a GPU?
# A graphical processing unit

# %% [markdown]
# Q11: What did Samuel mean by weight assignments
# These are variables that have some value that is used to guide the prediction.

# %% [markdown]
# Q12: What term do we normally use in deep learning for what Samuel called weights?
# parameters

# %% [markdown]
# Q13: Draw a picture of Samuel's deep learning model

# %% [markdown]
# Q14: Why is it hard to understand why a DL model makes a particular prediction

# %% [markdown]
# Q15: What is the name of the theorem that shows a neural network can solve any problem to any level of completicy
# This is the neural network shown with the proof of the Universal Approximation Theorem
# a neural network is a particular kind of machine learning model, which fits right in to Samuel’s original conception. Neural networks are special because they are highly flexible, which means they can solve an unusually wide range of problems just by finding the right weights.
#
# Howard, Jeremy; Gugger, Sylvain. Deep Learning for Coders with fastai and PyTorch: AI Applications Without a PhD (p. 56). (Function). Kindle Edition.

# %% [markdown]
# Q16: What do you need to train a model?
# You need data with labels. It is not enough to have pictures of cats and dogs in some way the nn must be able to know
# thqt  is a picture of a cat or dog to test its predictions. when organizations say they do not have enough data
# they often mean they don't have enough labeled data

# %% [markdown]
# Q17: How could a feedback loop impact the rollout of a predictive policing model?

# %% [markdown]
# Q18: Do we always have to use a 224 X 224 image with the cat recognition model

# %% [markdown]
# Q19: What is the difference between classification and regression?
# classi

# %% [markdown]
# Q20: What is a validation set and why do we need them?
